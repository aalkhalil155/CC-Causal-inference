# %% [markdown]
# # causal-dragonnet-advanced (Colab Demo)\n\nRun training end-to-end.

# %%
# If you opened this notebook from GitHub in Colab, it may already be in the repo.
# Otherwise:
# !git clone <YOUR_REPO_URL>
# %cd causal-dragonnet-advanced

# %%
# !pip install -r requirements.txt

# %%
# !python -m src.train
